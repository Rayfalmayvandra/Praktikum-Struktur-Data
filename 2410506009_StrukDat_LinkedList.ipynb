# %% [markdown]
# <a href="https://colab.research.google.com/github/Rayfalmayvandra/Praktikum-Struktur-Data/blob/main/2410506009_StrukDat_LinkedList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Latihan** **1**

# %%
#Definisi Node dalam Linked List
class TaskNode:
    def __init__(self, task_name):
        self.task_name = task_name #Menyimpan nama tugas
        self.next = None #Pointer ke tugas berikutnya

#Definisi LInked List untuk Daftar Tugas
class TaskList:
    def __init__(self):
        self.head = None #Awalnya tidak ada tugas (daftar kosong)

      #Menambahkan tugas ke Linked List
    def add_task(self, taks_name):
        new_task = TaskNode(task_name)
        if not self.head:
            self.head = new_task #Jika list kosong, tugas pertama menjadi head

        else:
            current = self.head
            while current.next: #Mencari node terakhir dalam list
                current = current.next
            current.next = new_task #Menambahkan tugas ke akhir list

        #Menampilkan daftar tugas
    def show_tasks(self):
            if not self.head:
                print("\n Tidak ada tugas hari ini!")
                return

            print("\n Daftar Tugas Hari ini:")
            current = self.head
            count = 1
            while current:
                print(f"{count}. {current.task_name}")
                current = current.next
                count += 1

# ===== Program Utama (Main) ====== #

#Membuat objek daftar tugas
task_list = TaskList()

#Meminta pengguna memasukkan jumlah tugas
num_tasks = int(input("Masukkan jumlah tugas hari ini: "))

#Loop untuk memasukkan tugas ke dalam Linked List
for i in range(1, num_tasks + 1):
    task_name = input(f"Masukkan tugas ke-{i}: ")
    task_list.add_task(task_name)

#Menampilkan hasil ]daftar tugas
task_list.show_tasks()
# Out:
# Masukkan jumlah tugas hari ini: 2
# Masukkan tugas ke-1: kalkulus
# Masukkan tugas ke-2: aljabar
#
#  Daftar Tugas Hari ini:
# 1. kalkulus
# 2. aljabar

# %%
#Latihan 1
class TaskNode:
    def __init__(self, task_name):
      self.task_name = task_name
      self.next = None

class Matkul_hari_Jumat:
    def __init__(self):
      self.head = None

    def add_task(self, task_name):
      new_task = TaskNode(task_name)
      if not self.head:
        self.head = new_task

      else:
        current = self.head
        while current.next:
          current = current.next
        current.next = new_task

    def show_tasks(self):
      if not self.head:
        print("\nTidak ada Matkul hari ini!")
        return

      print("\nJadwal Matkul Hari Jumat:")
      current = self.head
      count = 1
      while current:
        print(f"{count}. {current.task_name}")
        current = current.next
        count += 1

task_list = Matkul_hari_Jumat()

num_tasks = int(input("Masukkan jumlah Matkul hari ini: "))

for i in range(1, num_tasks + 1):
    task_name = input(f"Masukkan Matkul ke-{i}: ")
    task_list.add_task(task_name)

task_list.show_tasks()
# Out:
# Masukkan jumlah Matkul hari ini: 0
#
# Tidak ada Matkul hari ini!

# %%
#Definisi Node dalam Doubly Linked List
class PageNode:
    def __init__(self, url):
        self.url = url #URL halaman web
        self.next = None #Pointer ke halaman berikutnya
        self.prev = None #Pointer ke halaman sebelumnya

#Definisi Doubly Linked List untuk RiwayaT Peramban
class BrowserHistory:
    def __init__(self):
        self.current = None #Pointer ke halaman yang sedang dibuka

    #Menambahkan halaman baru ke dalam riwayat
    def visit_page(self, url):
        new_page = PageNode(url)
        if not self.current:
            self.current = new_page #Jika riwayat kosong, halaman pertama menjadi halaman pertama
        else:
            new_page.prev = self.current
            self.current.next = new_page
            self.current = new_page #Pindahkan posisi ke halaman baru

    #Menampilkan riwayat kunjungan
    def show_history(self):
        if not self.current:
            print("\n Riwayat kosong!")
            return

        print("\n Riwayat Peramban Web:")
        temp = self.current
        while temp.prev: #Kembali ke halaman pertama
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.url}")
            temp = temp.next
            count += 1

    #Navigasi mundur ke halaman sebelumnya
    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke: {self.current.url}")
        else:
            print("\n Tidak bisa maju, ini adalah halaman terakhir!.")
    #Navigasi maju ke halaman berikutnya
    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\n Anda maju ke: {self.current.url}")
        else:
            print("\n Tidak bisa mundur, ini adalah halaman terakhir!.")

# ===== Program Utama (Main) ===== #

#Membuat objek riwayat peramban
history = BrowserHistory()

#Meminta pengguna memasukkan jumlah halaman yang dikunjungi
num_pages = int(input("\nMasukkan jumlah halaman yang dikunjungi: "))

#Loop untuk memasukkan URL halaman ke dalam riwayat peramban
for i in range(1, num_pages + 1):

    url = input(f"Masukkan URL halaman ke-{i}: ")
    history.visit_page(url)

#Menampilkan riwayat yang telah dimasukkan
history.show_history()

#Menu Navigasi pengguna
while True:
    command = input("\n Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar. \nMasukkan perintah: "). lower()

    if command == 'b':
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\n Keluar dari riwayat peramban.")
        break
    else:
        print("\n Perintah tidak dikenal.")
# Out:
# Masukkan jumlah halaman yang dikunjungi: 2
# Masukkan URL halaman ke-1: Google
# Masukkan URL halaman ke-2: Medium
#
#  Riwayat Peramban Web:
# 1. Google
# 2. Medium
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  Anda kembali ke: Google
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: f
#
#  Anda maju ke: Medium
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: f
#
#  Tidak bisa mundur, ini adalah halaman terakhir!.
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: x
#
#  Keluar dari riwayat peramban.

# %%
#Latihan 2
class FolderNode:
    def __init__(self, folder):
        self.folder = folder
        self.next = None
        self.prev = None

class FolderHistory:
    def __init__(self):
        self.current = None

    def visit_folder(self, folder):
        new_folder = FolderNode(folder)
        if not self.current:
            self.current = new_folder
        else:
            new_folder.prev = self.current
            self.current.next = new_folder
            self.current = new_folder

    def show_history(self):
        if not self.current:
            print("\n Riwayat kosong!")
            return

        print("\n Riwayat folder:")
        temp = self.current
        while temp.prev:
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.folder}")
            temp = temp.next
            count += 1

    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke: {self.current.folder}")
        else:
            print("\n Tidak bisa maju, ini adalah halaman terakhir!.")

    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\n Anda maju ke: {self.current.folder}")
        else:
            print("\n Tidak bisa mundur, ini adalah halaman terakhir!.")


history = FolderHistory()

num_folder = int(input("\nMasukkan jumlah halaman yang dikunjungi: "))

for i in range(1, num_folder + 1):

    folder = input(f"Masukkan Folder halaman ke-{i}: ")
    history.visit_folder(folder)

history.show_history()

while True:
    command = input("\n Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar. \nMasukkan perintah: "). lower()

    if command == 'b':
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\n Keluar dari riwayat peramban.")
        break
    else:
        print("\n Perintah tidak dikenal.")
# Out:
# Masukkan jumlah halaman yang dikunjungi: 9
# Masukkan Folder halaman ke-1: Kuliah
# Masukkan Folder halaman ke-2: Bahasa Indonesia
# Masukkan Folder halaman ke-3: Bahasa Inggris
# Masukkan Folder halaman ke-4: Kalkulus Lanjut
# Masukkan Folder halaman ke-5: Fisika Lanjut
# Masukkan Folder halaman ke-6: Biologi
# Masukkan Folder halaman ke-7: Pendidikan Pancasila
# Masukkan Folder halaman ke-8: Praktikum Struktur Data
# Masukkan Folder halaman ke-9: Praktikum Basis Data
#
#  Riwayat folder:
# 1. Kuliah
# 2. Bahasa Indonesia
# 3. Bahasa Inggris
# 4. Kalkulus Lanjut
# 5. Fisika Lanjut
# 6. Biologi
# 7. Pendidikan Pancasila
# 8. Praktikum Struktur Data
# 9. Praktikum Basis Data
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: f
#
#  Tidak bisa mundur, ini adalah halaman terakhir!.
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  Anda kembali ke: Praktikum Struktur Data
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  Anda kembali ke: Pendidikan Pancasila
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  Anda kembali ke: Biologi
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: f
#
#  Anda maju ke: Pendidikan Pancasila
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: x
#
#  Keluar dari riwayat peramban.

# %% [markdown]
# # **Latihan** **3**

# %%
# Definisi Node dalam Circular Linked List
class SongNode:
    def __init__(self, title):
        self.title = title  # Menyimpan judul lagu
        self.next = None  # Pointer ke lagu berikutnya

# Definisi Circular Linked List untuk Playlist Lagu
class Playlist:
    def __init__(self):
        self.current = None  # Lagu yang sedang diputar

    # Menambahkan lagu ke dalam playlist
    def add_song(self, title):
        new_song = SongNode(title)
        if not self.current:
            self.current = new_song
            self.current.next = self.current  # Menghubungkan ke dirinya sendiri (Circular)
        else:
            temp = self.current
            while temp.next != self.current:  # Mencari lagu terakhir
                temp = temp.next
            temp.next = new_song  # Menambahkan lagu di akhir
            new_song.next = self.current  # Menghubungkan kembali ke awal

    # Menampilkan daftar lagu dalam playlist
    def show_playlist(self):
        if not self.current:
            print("\nPlaylist kosong!")
            return

        print("\nPlaylist Lagu Anda:")
        temp = self.current
        count = 1
        while True:
            print(f"{count}. {temp.title}")
            temp = temp.next
            count += 1
            if temp == self.current:  # Berhenti jika sudah kembali ke awal
                break

    # Memutar lagu berikutnya dalam playlist
    def next_song(self):
        if self.current:
            self.current = self.current.next
            print(f"\nMemutar: {self.current.title}")

# ====== Program Utama (Main) ====== #

# Membuat objek playlist
playlist = Playlist()

# Meminta pengguna memasukkan jumlah lagu
num_songs = int(input("\nMasukkan jumlah lagu dalam playlist: "))

# Loop untuk memasukkan lagu ke dalam Circular Linked List
for i in range(1, num_songs + 1):
    title = input(f"Masukkan judul lagu ke-{i}: ")
    playlist.add_song(title)

# Menampilkan daftar lagu
playlist.show_playlist()

# Menu navigasi pengguna
while True:
    command = input("\nTekan 'n' untuk lagu berikutnya, Tekan 'x' untuk keluar.\nMasukkan perintah: ").lower()

    if command == 'n':
        playlist.next_song()
    elif command == 'x':
        print("\nKeluar dari pemutar musik.")
        break
    else:
        print("\nPerintah tidak dikenal.")
# Out:
# Masukkan jumlah lagu dalam playlist: 3
# Masukkan judul lagu ke-1: Is This It
# Masukkan judul lagu ke-2: You Only Live At Once
# Masukkan judul lagu ke-3: Reptilia
#
# Playlist Lagu Anda:
# 1. Is This It
# 2. You Only Live At Once
# 3. Reptilia
#
# Tekan 'n' untuk lagu berikutnya, Tekan 'x' untuk keluar.
# Masukkan perintah: n
#
# Memutar: You Only Live At Once
#
# Tekan 'n' untuk lagu berikutnya, Tekan 'x' untuk keluar.
# Masukkan perintah: n
#
# Memutar: Reptilia
#
# Tekan 'n' untuk lagu berikutnya, Tekan 'x' untuk keluar.
# Masukkan perintah: x
#
# Keluar dari pemutar musik.

# %%
class Node:
    def __init__(self, data):
        self.data = data  # Menyimpan nilai node
        self.next = None  # Pointer ke node berikutnya

class LinkedList:
    def __init__(self):
        self.head = None  # Awalnya, daftar kosong

    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def add_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    def add_at_position(self, position, data):
        if position < 0:
            print("Posisi tidak valid!")
            return
        new_node = Node(data)
        if position == 0:
            self.add_at_beginning(data)
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp or not temp.next:
                print("Posisi melebihi panjang daftar!")
                return
            temp = temp.next
        new_node.next = temp.next
        temp.next = new_node

    def delete_at_beginning(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        self.head = self.head.next

    def delete_at_end(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if not self.head.next:
            self.head = None
            return
        temp = self.head
        while temp.next.next:
            temp = temp.next
        temp.next = None

    def delete_at_position(self, position):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if position == 0:
            self.head = self.head.next
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp or not temp.next:
                print("Posisi tidak ditemukan!")
                return
            temp = temp.next
        temp.next = temp.next.next

    def search(self, key):
        temp = self.head
        while temp:
            if temp.data == key:
                print(f"Elemen {key} ditemukan dalam daftar!")
                return
            temp = temp.next
        print(f"Elemen {key} tidak ditemukan dalam daftar.")

    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    def display(self):
        if not self.head:
            print("Daftar kosong!")
            return
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")

# Program Utama
ll = LinkedList()
num_elements = int(input("Masukkan jumlah awal elemen dalam daftar: "))
for i in range(num_elements):
    data = int(input(f"Masukkan data ke-{i+1}: "))
    ll.add_at_end(data)

while True:
    print("\nPilih Operasi:")
    print("1. Tambah elemen di awal")
    print("2. Tambah elemen di akhir")
    print("3. Tambah elemen di posisi tertentu")
    print("4. Hapus elemen di awal")
    print("5. Hapus elemen di akhir")
    print("6. Hapus elemen di posisi tertentu")
    print("7. Cari elemen dalam daftar")
    print("8. Balikkan daftar")
    print("9. Tampilkan daftar")
    print("0. Keluar")

    choice = int(input("\nMasukkan pilihan: "))

    if choice == 1:
        data = int(input("Masukkan data yang ingin ditambahkan di awal: "))
        ll.add_at_beginning(data)
    elif choice == 2:
        data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))
        ll.add_at_end(data)
    elif choice == 3:
        position = int(input("Masukkan posisi untuk menambahkan data: "))
        data = int(input("Masukkan data yang ingin ditambahkan: "))
        ll.add_at_position(position, data)
    elif choice == 4:
        ll.delete_at_beginning()
    elif choice == 5:
        ll.delete_at_end()
    elif choice == 6:
        position = int(input("Masukkan posisi elemen yang ingin dihapus: "))
        ll.delete_at_position(position)
    elif choice == 7:
        key = int(input("Masukkan elemen yang ingin dicari: "))
        ll.search(key)
    elif choice == 8:
        ll.reverse()
        print("Daftar berhasil dibalik!")
    elif choice == 9:
        ll.display()
    elif choice == 0:
        print("\nKeluar dari program.")
        break
    else:
        print("Pilihan tidak valid, silakan coba lagi!")
# Out:
# Masukkan jumlah awal elemen dalam daftar: 3
# Masukkan data ke-1: 3
# Masukkan data ke-2: 2
# Masukkan data ke-3: 5
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 1
# Masukkan data yang ingin ditambahkan di awal: 4
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 2
# Masukkan data yang ingin ditambahkan di akhir: 2
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 3
# Masukkan posisi untuk menambahkan data: 2
# Masukkan data yang ingin ditambahkan: 1
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 4
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 1
# Masukkan data yang ingin ditambahkan di awal: 4
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 5
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 2
# Masukkan data yang ingin ditambahkan di akhir: 5
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 6
# Masukkan posisi elemen yang ingin dihapus: 2
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 3
# Masukkan posisi untuk menambahkan data: 1
# Masukkan data yang ingin ditambahkan: 7
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 7
# Masukkan elemen yang ingin dicari: 7
# Elemen 7 ditemukan dalam daftar!
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 8
# Daftar berhasil dibalik!
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 9
# 5 -> 5 -> 2 -> 3 -> 7 -> 4 -> None
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 0
#
# Keluar dari program.
